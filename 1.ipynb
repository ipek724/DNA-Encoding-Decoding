# %%
import PyPDF2
import re
import string

# %%
object = PyPDF2.PdfFileReader("Handbook of Data Compression, 5th Edition.pdf")

# %%
NumPages = object.getNumPages()

# Enter Character here

String = ["a","b","c","d"]


#Define initial values
import json

with open('mydic.json') as f:
    mydic = json.load(f)


with open('mydict.json') as f:
    mydict = json.load(f)

# cc=0
sc=0
# mydic={}
# mydict={}
# # Extract text and do the search
for String in String:
    for i in range(0, NumPages):
        PageObj = object.getPage(i)
        Text = PageObj.extractText()
    
        if re.search(String,Text):
            # cc=cc+1
            sc=sc+1
#     mydic.update(dict.fromkeys(String,cc))
#     cc=0
# mydict.update(mydic)
# for x in mydict.keys():
#     h=mydict[x]
    # h/=5457
    # mydict[x]=h
#Print Output Dic
print("--"*78,"sum of character","--"*78,"\n")
print("sum of character=" ,sc,"\n")
print("--"*80,"Character Value","--"*82,"\n")
print("Character Value:",mydic,"\n")
print("--"*78,"Probabilistic value","--"*78,"\n")
print("Probabilistic value:",mydict,"\n")
# Out:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------ sum of character ------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# sum of character= 5457
#
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------- Character Value --------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# ...
